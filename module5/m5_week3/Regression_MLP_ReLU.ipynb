# %% [markdown]
# ## **0. Download dataset**
# **Note:** If you can't download using gdown due to limited number of downloads, please download it manually and upload it to your drive, then copy it from the drive to colab.
# ```python
# from google.colab import drive
#
# drive.mount('/content/drive')
# !cp /path/to/dataset/on/your/drive .
# ```

# %%
# https://drive.google.com/file/d/1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu/view?usp=sharing
# !gdown --id 1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu
# To: /content/Auto_MPG_data.csv
# 100% 15.4k/15.4k [00:00<00:00, 43.0MB/s]

# %% [markdown]
# ## **1. Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

# %% [markdown]
# ## **2. Read dataset**

# %%
dataset_path = '/content/Auto_MPG_data.csv'
dataset = pd.read_csv(dataset_path)
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0        86.0  2790.0          15.6
# 388  44.0          4          97.0        52.0  2130.0          24.6
# 389  32.0          4         135.0        84.0  2295.0          11.6
# 390  28.0          4         120.0        79.0  2625.0          18.6
# 391  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Europe  Japan  USA
# 0            70       0      0    1
# 1            70       0      0    1
# 2            70       0      0    1
# 3            70       0      0    1
# 4            70       0      0    1
# ..          ...     ...    ...  ...
# 387          82       0      0    1
# 388          82       1      0    0
# 389          82       0      0    1
# 390          82       0      0    1
# 391          82       0      0    1
#
# [392 rows x 10 columns]

# %% [markdown]
# ## **3. Preprocessing data**

# %% [markdown]
# ### **3.1. X, y split**

# %%
X = dataset.drop(columns='MPG').values
y = dataset['MPG'].values

# %% [markdown]
# ### **3.2. Train/val/test split**

# %%
val_size = 0.2
test_size = 0.125
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
print(f'Number of training samples: {X_train.shape[0]}')
print(f'Number of val samples: {X_val.shape[0]}')
print(f'Number of test samples: {X_test.shape[0]}')
# Out:
# Number of training samples: 273
# Number of val samples: 79
# Number of test samples: 40

# %% [markdown]
# ### **3.3. Data Normalization**

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)

y_train = torch.tensor(y_train, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %% [markdown]
# ## **4. Create PyTorch DataLoader**

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
test_dataset = CustomDataset(X_test, y_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## **5. Build MLP network**

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.linear3 = nn.Linear(hidden_dims, output_dims)

    def forward(self, x):
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        out = self.linear3(x)
        return out.squeeze()

# %% [markdown]
# ## **6. Training**

# %%
def r_squared(y_true, y_pred):
    y_true = torch.Tensor(y_true).to(device)
    y_pred = torch.Tensor(y_pred).to(device)
    mean = torch.mean(y_true)
    ss_tot = torch.sum((y_true - mean) ** 2)
    ss_res = torch.sum((y_true - y_pred) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

# %%
input_dims = X_train.shape[1]
hidden_dims = 64
output_dims = 1

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

# %%
lr = 1e-2
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
epochs = 100
train_losses = []
val_losses = []
train_r2 = []
val_r2 = []

# %%
for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    val_target = []
    train_predict = []
    val_predict = []
    model.train()
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        train_predict += outputs.tolist()
        train_target += y_samples.tolist()
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    train_r2.append(r_squared(train_target, train_predict))
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device)
            y_samples = y_samples.to(device)
            outputs = model(X_samples)
            val_predict += outputs.tolist()
            val_target += y_samples.tolist()
            loss = criterion(outputs, y_samples)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_r2.append(r_squared(val_target, val_predict))
    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 440.749	Validation loss: 239.848
#
# EPOCH 2:	Training loss: 319.848	Validation loss: 378.137
#
# EPOCH 3:	Training loss: 137.975	Validation loss: 75.583
#
# EPOCH 4:	Training loss: 60.138	Validation loss: 229.995
#
# EPOCH 5:	Training loss: 63.686	Validation loss: 19.501
#
# EPOCH 6:	Training loss: 32.794	Validation loss: 9.242
#
# EPOCH 7:	Training loss: 18.608	Validation loss: 13.409
#
# EPOCH 8:	Training loss: 12.835	Validation loss: 15.417
#
# EPOCH 9:	Training loss: 26.520	Validation loss: 53.033
#
# EPOCH 10:	Training loss: 13.487	Validation loss: 7.219
#
# EPOCH 11:	Training loss: 13.648	Validation loss: 17.014
#
# EPOCH 12:	Training loss: 10.456	Validation loss: 9.159
#
# EPOCH 13:	Training loss: 15.564	Validation loss: 6.045
#
# EPOCH 14:	Training loss: 10.559	Validation loss: 8.344
#
# EPOCH 15:	Training loss: 15.164	Validation loss: 7.679
#
# EPOCH 16:	Training loss: 16.599	Validation loss: 9.511
#
# EPOCH 17:	Training loss: 8.466	Validation loss: 8.797
#
# EPOCH 18:	Training loss: 7.476	Validation loss: 5.269
#
# EPOCH 19:	Training loss: 8.056	Validation loss: 6.398
#
# EPOCH 20:	Training loss: 11.044	Validation loss: 14.275
#
# EPOCH 21:	Training loss: 9.966	Validation loss: 6.164
#
# EPOCH 22:	Training loss: 8.028	Validation loss: 31.607
#
# EPOCH 23:	Training loss: 16.805	Validation loss: 14.271
#
# EPOCH 24:	Training loss: 11.447	Validation loss: 5.500
#
# EPOCH 25:	Training loss: 7.205	Validation loss: 5.465
#
# EPOCH 26:	Training loss: 7.745	Validation loss: 7.775
#
# EPOCH 27:	Training loss: 11.260	Validation loss: 5.089
#
# EPOCH 28:	Training loss: 9.650	Validation loss: 21.337
#
# EPOCH 29:	Training loss: 15.020	Validation loss: 5.446
#
# EPOCH 30:	Training loss: 7.160	Validation loss: 6.841
#
# EPOCH 31:	Training loss: 6.174	Validation loss: 5.279
#
# EPOCH 32:	Training loss: 7.297	Validation loss: 6.452
#
# EPOCH 33:	Training loss: 7.734	Validation loss: 9.426
#
# EPOCH 34:	Training loss: 5.979	Validation loss: 6.166
#
# EPOCH 35:	Training loss: 6.975	Validation loss: 4.906
#
# EPOCH 36:	Training loss: 6.216	Validation loss: 5.866
#
# EPOCH 37:	Training loss: 6.953	Validation loss: 6.708
#
# EPOCH 38:	Training loss: 7.621	Validation loss: 6.936
#
# EPOCH 39:	Training loss: 7.098	Validation loss: 6.576
#
# EPOCH 40:	Training loss: 6.512	Validation loss: 4.945
#
# EPOCH 41:	Training loss: 5.846	Validation loss: 4.937
#
# EPOCH 42:	Training loss: 6.563	Validation loss: 5.356
#
# EPOCH 43:	Training loss: 7.349	Validation loss: 11.741
#
# EPOCH 44:	Training loss: 12.502	Validation loss: 13.274
#
# EPOCH 45:	Training loss: 9.090	Validation loss: 10.554
#
# EPOCH 46:	Training loss: 10.929	Validation loss: 5.623
#
# EPOCH 47:	Training loss: 6.270	Validation loss: 10.414
#
# EPOCH 48:	Training loss: 5.594	Validation loss: 7.369
#
# EPOCH 49:	Training loss: 7.917	Validation loss: 4.655
#
# EPOCH 50:	Training loss: 5.240	Validation loss: 5.336
#
# EPOCH 51:	Training loss: 7.508	Validation loss: 9.860
#
# EPOCH 52:	Training loss: 7.611	Validation loss: 9.910
#
# EPOCH 53:	Training loss: 7.995	Validation loss: 5.219
#
# EPOCH 54:	Training loss: 6.393	Validation loss: 6.501
#
# EPOCH 55:	Training loss: 6.187	Validation loss: 7.341
#
# EPOCH 56:	Training loss: 6.417	Validation loss: 10.386
#
# EPOCH 57:	Training loss: 6.939	Validation loss: 8.017
#
# EPOCH 58:	Training loss: 11.144	Validation loss: 4.544
#
# EPOCH 59:	Training loss: 7.983	Validation loss: 5.876
#
# EPOCH 60:	Training loss: 5.871	Validation loss: 5.454
#
# EPOCH 61:	Training loss: 6.648	Validation loss: 10.781
#
# EPOCH 62:	Training loss: 7.461	Validation loss: 4.863
#
# EPOCH 63:	Training loss: 6.655	Validation loss: 6.181
#
# EPOCH 64:	Training loss: 6.108	Validation loss: 5.771
#
# EPOCH 65:	Training loss: 5.036	Validation loss: 6.224
#
# EPOCH 66:	Training loss: 6.248	Validation loss: 5.644
#
# EPOCH 67:	Training loss: 6.787	Validation loss: 6.489
#
# EPOCH 68:	Training loss: 6.323	Validation loss: 5.648
#
# EPOCH 69:	Training loss: 5.301	Validation loss: 11.075
#
# EPOCH 70:	Training loss: 6.881	Validation loss: 7.128
#
# EPOCH 71:	Training loss: 5.636	Validation loss: 4.821
#
# EPOCH 72:	Training loss: 6.367	Validation loss: 12.885
#
# EPOCH 73:	Training loss: 6.265	Validation loss: 19.199
#
# EPOCH 74:	Training loss: 10.277	Validation loss: 5.772
#
# EPOCH 75:	Training loss: 4.821	Validation loss: 5.284
#
# EPOCH 76:	Training loss: 4.731	Validation loss: 5.647
#
# EPOCH 77:	Training loss: 5.291	Validation loss: 9.128
#
# EPOCH 78:	Training loss: 6.342	Validation loss: 4.692
#
# EPOCH 79:	Training loss: 4.502	Validation loss: 6.374
#
# EPOCH 80:	Training loss: 5.688	Validation loss: 7.725
#
# EPOCH 81:	Training loss: 5.451	Validation loss: 6.473
#
# EPOCH 82:	Training loss: 6.563	Validation loss: 6.994
#
# EPOCH 83:	Training loss: 5.719	Validation loss: 5.984
#
# EPOCH 84:	Training loss: 6.683	Validation loss: 9.578
#
# EPOCH 85:	Training loss: 6.263	Validation loss: 13.010
#
# EPOCH 86:	Training loss: 7.542	Validation loss: 5.084
#
# EPOCH 87:	Training loss: 4.526	Validation loss: 6.615
#
# EPOCH 88:	Training loss: 4.903	Validation loss: 6.909
#
# EPOCH 89:	Training loss: 4.745	Validation loss: 5.014
#
# EPOCH 90:	Training loss: 5.200	Validation loss: 7.108
#
# EPOCH 91:	Training loss: 5.127	Validation loss: 9.586
#
# EPOCH 92:	Training loss: 6.286	Validation loss: 5.537
#
# EPOCH 93:	Training loss: 6.066	Validation loss: 6.738
#
# EPOCH 94:	Training loss: 8.701	Validation loss: 4.969
#
# EPOCH 95:	Training loss: 6.077	Validation loss: 4.916
#
# EPOCH 96:	Training loss: 4.486	Validation loss: 5.537
#
# EPOCH 97:	Training loss: 4.467	Validation loss: 9.132
#
# EPOCH 98:	Training loss: 5.729	Validation loss: 5.378
#
# EPOCH 99:	Training loss: 4.801	Validation loss: 5.162
#
# EPOCH 100:	Training loss: 4.858	Validation loss: 4.777

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_r2, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='R2')
ax[1, 0].set_title('Training R2')

ax[1, 1].plot(val_r2, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='R2')
ax[1, 1].set_title('Validation R2')

plt.show()

# %% [markdown]
# ## **7. Evaluation**

# %%
model.eval()
with torch.no_grad():
    y_hat = model(X_val)
    val_set_r2 = r_squared(y_hat, y_val)
    print('Evaluation on validation set:')
    print(f'R2: {val_set_r2}')
# Out:
# Evaluation on validation set:
# R2: 0.9094057679176331
